# %% [markdown]
# <a href="https://colab.research.google.com/github/valeriodc95/Belief-Network/blob/master/bn_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, shutil
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# # tf.data.Dataset: input pipeline
# Dataset loading, preparation of the input_fn which feeds the estimator with data and serving function declaration.

# %%
train, test = tf.keras.datasets.mnist.load_data()
tr_images, tr_labels = np.reshape(train[0], (60000, -1)), train[1]
tr_images = tr_images/255
tr_img, eval_img, tr_lab, eval_lab = train_test_split(tr_images, tr_labels, 
                                                      test_size=10000, 
                                                      random_state=42,
                                                      stratify=tr_labels)

# %%
def data_input_fn(images, labels=None, phase='eval'):
    if phase == 'train':
        def train_input_fn():
            dataset = tf.data.Dataset.from_tensor_slices(({'image': images}, labels))
            dataset = dataset.shuffle(buffer_size=5000, reshuffle_each_iteration=True)
            dataset = dataset.repeat()
            dataset = dataset.batch(batch_size=BATCH_SIZE)
            dataset = dataset.prefetch(buffer_size=-1) # autotunes the buffer size
            
            return dataset
        
        return train_input_fn
    
    if phase == 'eval':
        def eval_input_fn():
            if labels is not None:
                dataset = tf.data.Dataset.from_tensor_slices(({'image': images}, labels))
            else:
                dataset = tf.data.Dataset.from_tensor_slices(({'image': images}))
            dataset = dataset.batch(batch_size=len(images))
            dataset = dataset.repeat() 
            
            return dataset
        
        return eval_input_fn
    
    if phase == 'test':
        def test_input_fn():
            dataset = tf.data.Dataset.from_tensor_slices(({'image': images}))
            dataset = dataset.batch(batch_size=len(images))
            
            return dataset
        
        return test_input_fn

def serving_input_rec_fn():
    serving_features = {'image': tf.placeholder(shape=(None, 784), dtype=tf.float32)}
    return tf.estimator.export.ServingInputReceiver(features=serving_features,
                                                    receiver_tensors=serving_features)

# %% [markdown]
# # RBM Training config

# %%
BATCH_SIZE = 100 #@param {type:"integer"}
EPOCHS = 100 #@param {type:"integer"}
L_RATE = 0.01 #@param {type:'number'}
HIDDEN_NEURONS = 100 #@param {type:"integer"}
model_dir = "rbm_train_dir" #@param {type:"string"}
N_CLASSES = 10 #@param {type:"integer"}
steps_per_epoch = 50000 // BATCH_SIZE

distribute = tf.contrib.distribute.DistributeConfig(
    train_distribute=tf.contrib.distribute.ParameterServerStrategy(num_gpus_per_worker=1),
    eval_distribute=tf.contrib.distribute.ParameterServerStrategy(num_gpus_per_worker=1))

run_config = tf.estimator.RunConfig(save_summary_steps=10,
                                    save_checkpoints_steps=steps_per_epoch,
                                    experimental_distribute=distribute)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:ParameterServerStrategy with compute_devices = ('/replica:0/task:0/device:GPU:0',), variable_device = '/device:GPU:0'
# INFO:tensorflow:ParameterServerStrategy with compute_devices = ('/replica:0/task:0/device:GPU:0',), variable_device = '/device:GPU:0'
# INFO:tensorflow:Initializing RunConfig with distribution strategies.
# INFO:tensorflow:Not using Distribute Coordinator.

# %% [markdown]
# # Belief Network model_fn
# Implementation of RBM inference, Contrastive Divergence for the parameters' update and train_op of the tf.estimator.

# %%
def untrained_rbm_inference(input_):
    
    v_input = tf.cast(input_['image'], dtype=tf.float32)
    
    with tf.variable_scope('rbm', reuse=tf.AUTO_REUSE):
        weights = tf.get_variable(name='weights',
                                  shape=(784, HIDDEN_NEURONS),
                                  initializer=tf.keras.initializers.RandomNormal(stddev=0.01, dtype=tf.float32),
                                  trainable=True)
        h_bias = tf.get_variable(name='bias',
                                 shape=(1, HIDDEN_NEURONS),
                                 initializer=tf.keras.initializers.Zeros(dtype=tf.float32),
                                 trainable=True)
        v_bias = tf.get_variable(name='tmp_v_bias',
                             shape=(1, 784),
                             initializer=tf.keras.initializers.Zeros(dtype=tf.float32),
                             trainable=True)
    # Computing the wake
    h_act = tf.math.sigmoid((v_input @ weights) + h_bias)
    wake = tf.expand_dims(v_input, axis=2) @ tf.expand_dims(h_act, axis=1)

    # Reconstructing input
    stoch_spike = tf.random_uniform(tf.shape(h_act), maxval=1, dtype=tf.float32)   
    h_spike = tf.math.ceil(h_act - stoch_spike)
    
    recon_input = tf.math.sigmoid((h_spike @ tf.transpose(weights)) + v_bias)


    # Computing the dream
    recon_h_act = tf.math.sigmoid((recon_input @ weights) + h_bias)   
    dream = tf.expand_dims(recon_input, axis=2) @ tf.expand_dims(recon_h_act, axis=1)

    return wake, dream, v_input, recon_input, h_act, recon_h_act

# %%
def rbm_train_model_fn(features, labels=None, mode=None, params=None):
    wake, dream, v_input, recon_input, h_act, recon_h_act = untrained_rbm_inference(features)
    err = tf.losses.mean_squared_error(v_input, recon_input)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        
        with tf.variable_scope('rbm', reuse=tf.AUTO_REUSE):
            weights = tf.get_variable('weights')
            h_bias = tf.get_variable('bias')
            v_bias = tf.get_variable('tmp_v_bias')

        with tf.control_dependencies([wake, dream]):
            w_update = tf.assign_add(weights, L_RATE * tf.reduce_mean(wake - dream, axis=0))
            hb_update = tf.assign_add(h_bias, L_RATE * tf.reduce_mean(h_act - recon_h_act, axis=0, keep_dims=True))
            vb_update = tf.assign_add(v_bias, L_RATE * tf.reduce_mean(v_input - recon_input, axis=0, keep_dims=True))
            gs_update = tf.assign_add(tf.train.get_or_create_global_step(), 1)
        
        rbm_train_op = tf.group(w_update, hb_update, vb_update, gs_update)
        return tf.estimator.EstimatorSpec(mode=mode,
                                          loss=err,
                                          train_op=rbm_train_op)
    
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(mode=mode,
                                          loss=err)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {'h_act': h_act}
        return tf.estimator.EstimatorSpec(mode=mode,
                                          predictions=predictions)

# %% [markdown]
# # RBM tf.estimator construction and training
# Now we put together everything together in order to wrap our model into the tf.estimator interface.

# %%
shutil.rmtree('rbm_train_dir')
rbm_estimator = tf.estimator.Estimator(model_fn=rbm_train_model_fn,
                                       model_dir=model_dir,
                                       config=run_config,
                                       params={},
                                       warm_start_from=None)
os.makedirs(rbm_estimator.eval_dir())

exporter = tf.estimator.BestExporter(name="best_rbm",
                                     serving_input_receiver_fn=serving_input_rec_fn,
                                     exports_to_keep=3)

early_stopping = tf.contrib.estimator.stop_if_no_decrease_hook(estimator=rbm_estimator,
                                                               metric_name='loss',
                                                               max_steps_without_decrease=5,
                                                               min_steps=5)

train_spec = tf.estimator.TrainSpec(input_fn=data_input_fn(tr_img, tr_lab, phase='train'),
                                    max_steps=EPOCHS * steps_per_epoch,
                                    hooks=[early_stopping])

eval_spec = tf.estimator.EvalSpec(input_fn=data_input_fn(eval_img, eval_lab, phase='eval'),
                                  steps=1,
                                  name='Validation',
                                  hooks=None,
                                  exporters=[exporter],
                                  start_delay_secs=0,
                                  throttle_secs=0)

tf.estimator.train_and_evaluate(estimator=rbm_estimator,
                                train_spec=train_spec,
                                eval_spec=eval_spec)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'rbm_train_dir', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': <tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7f886e39a2b0>, '_device_fn': None, '_protocol': None, '_eval_distribute': <tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7f886e39a400>, '_experimental_distribute': DistributeConfig(train_distribute=<tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7f886e39a2b0>, eval_distribute=<tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7f886e39a400>, remote_cluster=None), '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f886e39a588>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 500 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:loss = 0.23152184, step = 0
# INFO:tensorflow:global_step/sec: 360.163
# INFO:tensorflow:loss = 0.07767115, step = 100 (0.279 sec)
# INFO:tensorflow:global_step/sec: 406.254
# INFO:tensorflow:loss = 0.06777034, step = 200 (0.249 sec)
# INFO:tensorflow:global_step/sec: 400.384
# INFO:tensorflow:loss = 0.063455366, step = 300 (0.248 sec)
# INFO:tensorflow:global_step/sec: 391.818
# INFO:tensorflow:loss = 0.058594584, step = 400 (0.253 sec)
# INFO:tensorflow:Saving checkpoints for 500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:18Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:19
# INFO:tensorflow:Saving dict for global step 500: global_step = 500, loss = 0.054859456
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: rbm_train_dir/model.ckpt-500
# INFO:tensorflow:Loading best metric from event files.
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:205: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352019'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.4619
# INFO:tensorflow:loss = 0.056203127, step = 500 (2.904 sec)
# INFO:tensorflow:global_step/sec: 376.644
# INFO:tensorflow:loss = 0.04971578, step = 600 (0.266 sec)
# INFO:tensorflow:global_step/sec: 373.06
# INFO:tensorflow:loss = 0.047141373, step = 700 (0.265 sec)
# INFO:tensorflow:global_step/sec: 402.833
# INFO:tensorflow:loss = 0.046840962, step = 800 (0.251 sec)
# INFO:tensorflow:global_step/sec: 400.198
# INFO:tensorflow:loss = 0.046509877, step = 900 (0.249 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:23
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.04443276
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: rbm_train_dir/model.ckpt-1000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352023'/saved_model.pb
# INFO:tensorflow:global_step/sec: 40.6199
# INFO:tensorflow:loss = 0.043880142, step = 1000 (2.459 sec)
# INFO:tensorflow:global_step/sec: 340.916
# INFO:tensorflow:loss = 0.041366264, step = 1100 (0.294 sec)
# INFO:tensorflow:global_step/sec: 359.102
# INFO:tensorflow:loss = 0.041428752, step = 1200 (0.280 sec)
# INFO:tensorflow:global_step/sec: 371.988
# INFO:tensorflow:loss = 0.042055294, step = 1300 (0.267 sec)
# INFO:tensorflow:global_step/sec: 405.271
# INFO:tensorflow:loss = 0.04104604, step = 1400 (0.247 sec)
# INFO:tensorflow:Saving checkpoints for 1500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:26Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:27
# INFO:tensorflow:Saving dict for global step 1500: global_step = 1500, loss = 0.03972684
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1500: rbm_train_dir/model.ckpt-1500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-1500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352027'/saved_model.pb
# INFO:tensorflow:global_step/sec: 33.1266
# INFO:tensorflow:loss = 0.039687663, step = 1500 (3.020 sec)
# INFO:tensorflow:global_step/sec: 348.352
# INFO:tensorflow:loss = 0.040212628, step = 1600 (0.285 sec)
# INFO:tensorflow:global_step/sec: 361.694
# INFO:tensorflow:loss = 0.036956478, step = 1700 (0.279 sec)
# INFO:tensorflow:global_step/sec: 377.958
# INFO:tensorflow:loss = 0.041680947, step = 1800 (0.262 sec)
# INFO:tensorflow:global_step/sec: 379.921
# INFO:tensorflow:loss = 0.037395105, step = 1900 (0.265 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:31
# INFO:tensorflow:Saving dict for global step 2000: global_step = 2000, loss = 0.03646535
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: rbm_train_dir/model.ckpt-2000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-2000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352031'/saved_model.pb
# INFO:tensorflow:global_step/sec: 36.4506
# INFO:tensorflow:loss = 0.037119195, step = 2000 (2.743 sec)
# INFO:tensorflow:global_step/sec: 310.405
# INFO:tensorflow:loss = 0.03664382, step = 2100 (0.320 sec)
# INFO:tensorflow:global_step/sec: 293.315
# INFO:tensorflow:loss = 0.03554051, step = 2200 (0.343 sec)
# INFO:tensorflow:global_step/sec: 363.779
# INFO:tensorflow:loss = 0.035572886, step = 2300 (0.275 sec)
# INFO:tensorflow:global_step/sec: 376.569
# INFO:tensorflow:loss = 0.036877636, step = 2400 (0.264 sec)
# INFO:tensorflow:Saving checkpoints for 2500 into rbm_train_dir/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:34Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-2500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:34
# INFO:tensorflow:Saving dict for global step 2500: global_step = 2500, loss = 0.03413351
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2500: rbm_train_dir/model.ckpt-2500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-2500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352034'/saved_model.pb
# INFO:tensorflow:global_step/sec: 41.1412
# INFO:tensorflow:loss = 0.033693854, step = 2500 (2.430 sec)
# INFO:tensorflow:global_step/sec: 343.664
# INFO:tensorflow:loss = 0.03356682, step = 2600 (0.293 sec)
# INFO:tensorflow:global_step/sec: 367.872
# INFO:tensorflow:loss = 0.032828063, step = 2700 (0.272 sec)
# INFO:tensorflow:global_step/sec: 378.374
# INFO:tensorflow:loss = 0.033524726, step = 2800 (0.264 sec)
# INFO:tensorflow:global_step/sec: 393.814
# INFO:tensorflow:loss = 0.034706347, step = 2900 (0.254 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:38
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, loss = 0.03230411
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: rbm_train_dir/model.ckpt-3000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-3000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352038'/saved_model.pb
# INFO:tensorflow:global_step/sec: 40.3196
# INFO:tensorflow:loss = 0.032884523, step = 3000 (2.479 sec)
# INFO:tensorflow:global_step/sec: 354.103
# INFO:tensorflow:loss = 0.034871332, step = 3100 (0.283 sec)
# INFO:tensorflow:global_step/sec: 355.26
# INFO:tensorflow:loss = 0.030411474, step = 3200 (0.283 sec)
# INFO:tensorflow:global_step/sec: 356.623
# INFO:tensorflow:loss = 0.030942911, step = 3300 (0.279 sec)
# INFO:tensorflow:global_step/sec: 377.971
# INFO:tensorflow:loss = 0.029849194, step = 3400 (0.265 sec)
# INFO:tensorflow:Saving checkpoints for 3500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:41Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-3500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:42
# INFO:tensorflow:Saving dict for global step 3500: global_step = 3500, loss = 0.030770082
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3500: rbm_train_dir/model.ckpt-3500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-3500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352042'/saved_model.pb
# INFO:tensorflow:global_step/sec: 32.2791
# INFO:tensorflow:loss = 0.029628782, step = 3500 (3.100 sec)
# INFO:tensorflow:global_step/sec: 312.792
# INFO:tensorflow:loss = 0.030203633, step = 3600 (0.320 sec)
# INFO:tensorflow:global_step/sec: 369.924
# INFO:tensorflow:loss = 0.03118749, step = 3700 (0.270 sec)
# INFO:tensorflow:global_step/sec: 389.112
# INFO:tensorflow:loss = 0.031069258, step = 3800 (0.256 sec)
# INFO:tensorflow:global_step/sec: 350.984
# INFO:tensorflow:loss = 0.030290991, step = 3900 (0.285 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:45Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:46
# INFO:tensorflow:Saving dict for global step 4000: global_step = 4000, loss = 0.029526915
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: rbm_train_dir/model.ckpt-4000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-4000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352046'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.9546
# INFO:tensorflow:loss = 0.027668666, step = 4000 (2.502 sec)
# INFO:tensorflow:global_step/sec: 339.582
# INFO:tensorflow:loss = 0.030787634, step = 4100 (0.294 sec)
# INFO:tensorflow:global_step/sec: 346.919
# INFO:tensorflow:loss = 0.03157779, step = 4200 (0.290 sec)
# INFO:tensorflow:global_step/sec: 368.36
# INFO:tensorflow:loss = 0.029253855, step = 4300 (0.271 sec)
# INFO:tensorflow:global_step/sec: 391.794
# INFO:tensorflow:loss = 0.029553054, step = 4400 (0.254 sec)
# INFO:tensorflow:Saving checkpoints for 4500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:49Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-4500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:49
# INFO:tensorflow:Saving dict for global step 4500: global_step = 4500, loss = 0.028508125
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4500: rbm_train_dir/model.ckpt-4500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-4500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352049'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.0556
# INFO:tensorflow:loss = 0.028081406, step = 4500 (2.560 sec)
# INFO:tensorflow:global_step/sec: 350.489
# INFO:tensorflow:loss = 0.027229067, step = 4600 (0.289 sec)
# INFO:tensorflow:global_step/sec: 358.112
# INFO:tensorflow:loss = 0.029631684, step = 4700 (0.278 sec)
# INFO:tensorflow:global_step/sec: 370.854
# INFO:tensorflow:loss = 0.026398048, step = 4800 (0.268 sec)
# INFO:tensorflow:global_step/sec: 383.563
# INFO:tensorflow:loss = 0.027967269, step = 4900 (0.263 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:52Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:53
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, loss = 0.027602307
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: rbm_train_dir/model.ckpt-5000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-5000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352053'/saved_model.pb
# INFO:tensorflow:global_step/sec: 36.1154
# INFO:tensorflow:loss = 0.02709282, step = 5000 (2.769 sec)
# INFO:tensorflow:global_step/sec: 373.232
# INFO:tensorflow:loss = 0.02834259, step = 5100 (0.269 sec)
# INFO:tensorflow:global_step/sec: 365.623
# INFO:tensorflow:loss = 0.028583523, step = 5200 (0.273 sec)
# INFO:tensorflow:global_step/sec: 382.731
# INFO:tensorflow:loss = 0.026268454, step = 5300 (0.260 sec)
# INFO:tensorflow:global_step/sec: 386.466
# INFO:tensorflow:loss = 0.029292889, step = 5400 (0.258 sec)
# INFO:tensorflow:Saving checkpoints for 5500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:00:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-5500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:00:57
# INFO:tensorflow:Saving dict for global step 5500: global_step = 5500, loss = 0.026832739
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5500: rbm_train_dir/model.ckpt-5500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-5500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352057'/saved_model.pb
# INFO:tensorflow:global_step/sec: 35.3287
# INFO:tensorflow:loss = 0.027925003, step = 5500 (2.831 sec)
# INFO:tensorflow:global_step/sec: 355.416
# INFO:tensorflow:loss = 0.026739284, step = 5600 (0.283 sec)
# INFO:tensorflow:global_step/sec: 344.503
# INFO:tensorflow:loss = 0.02631692, step = 5700 (0.289 sec)
# INFO:tensorflow:global_step/sec: 374.537
# INFO:tensorflow:loss = 0.024483237, step = 5800 (0.268 sec)
# INFO:tensorflow:global_step/sec: 381.612
# INFO:tensorflow:loss = 0.026873384, step = 5900 (0.262 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:01
# INFO:tensorflow:Saving dict for global step 6000: global_step = 6000, loss = 0.026223782
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: rbm_train_dir/model.ckpt-6000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-6000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352061'/saved_model.pb
# INFO:tensorflow:global_step/sec: 35.4261
# INFO:tensorflow:loss = 0.025624095, step = 6000 (2.820 sec)
# INFO:tensorflow:global_step/sec: 341.985
# INFO:tensorflow:loss = 0.02784066, step = 6100 (0.295 sec)
# INFO:tensorflow:global_step/sec: 334.399
# INFO:tensorflow:loss = 0.026280649, step = 6200 (0.297 sec)
# INFO:tensorflow:global_step/sec: 370.071
# INFO:tensorflow:loss = 0.026678473, step = 6300 (0.272 sec)
# INFO:tensorflow:global_step/sec: 367.522
# INFO:tensorflow:loss = 0.025040418, step = 6400 (0.272 sec)
# INFO:tensorflow:Saving checkpoints for 6500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:04Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-6500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:05
# INFO:tensorflow:Saving dict for global step 6500: global_step = 6500, loss = 0.025630996
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6500: rbm_train_dir/model.ckpt-6500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-6500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352065'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.3542
# INFO:tensorflow:loss = 0.024801606, step = 6500 (2.604 sec)
# INFO:tensorflow:global_step/sec: 346.419
# INFO:tensorflow:loss = 0.026306987, step = 6600 (0.292 sec)
# INFO:tensorflow:global_step/sec: 359.488
# INFO:tensorflow:loss = 0.025904713, step = 6700 (0.277 sec)
# INFO:tensorflow:global_step/sec: 365.926
# INFO:tensorflow:loss = 0.026193634, step = 6800 (0.274 sec)
# INFO:tensorflow:global_step/sec: 389.427
# INFO:tensorflow:loss = 0.02564237, step = 6900 (0.257 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:08Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:08
# INFO:tensorflow:Saving dict for global step 7000: global_step = 7000, loss = 0.025100619
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: rbm_train_dir/model.ckpt-7000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-7000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352068'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.2919
# INFO:tensorflow:loss = 0.025214221, step = 7000 (2.610 sec)
# INFO:tensorflow:global_step/sec: 339.795
# INFO:tensorflow:loss = 0.025410779, step = 7100 (0.293 sec)
# INFO:tensorflow:global_step/sec: 374.152
# INFO:tensorflow:loss = 0.02540847, step = 7200 (0.270 sec)
# INFO:tensorflow:global_step/sec: 375.952
# INFO:tensorflow:loss = 0.024245461, step = 7300 (0.265 sec)
# INFO:tensorflow:global_step/sec: 391.731
# INFO:tensorflow:loss = 0.026329458, step = 7400 (0.254 sec)
# INFO:tensorflow:Saving checkpoints for 7500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:12Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-7500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:13
# INFO:tensorflow:Saving dict for global step 7500: global_step = 7500, loss = 0.024651214
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7500: rbm_train_dir/model.ckpt-7500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-7500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352073'/saved_model.pb
# INFO:tensorflow:global_step/sec: 32.0787
# INFO:tensorflow:loss = 0.024124838, step = 7500 (3.119 sec)
# INFO:tensorflow:global_step/sec: 338.597
# INFO:tensorflow:loss = 0.026941242, step = 7600 (0.295 sec)
# INFO:tensorflow:global_step/sec: 358.419
# INFO:tensorflow:loss = 0.024090227, step = 7700 (0.278 sec)
# INFO:tensorflow:global_step/sec: 379.203
# INFO:tensorflow:loss = 0.026034577, step = 7800 (0.267 sec)
# INFO:tensorflow:global_step/sec: 379.512
# INFO:tensorflow:loss = 0.025588516, step = 7900 (0.261 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:16Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:16
# INFO:tensorflow:Saving dict for global step 8000: global_step = 8000, loss = 0.024231626
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: rbm_train_dir/model.ckpt-8000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-8000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352076'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.3475
# INFO:tensorflow:loss = 0.023666093, step = 8000 (2.609 sec)
# INFO:tensorflow:global_step/sec: 311.037
# INFO:tensorflow:loss = 0.025716582, step = 8100 (0.319 sec)
# INFO:tensorflow:global_step/sec: 333.126
# INFO:tensorflow:loss = 0.024231425, step = 8200 (0.303 sec)
# INFO:tensorflow:global_step/sec: 335.776
# INFO:tensorflow:loss = 0.024058811, step = 8300 (0.295 sec)
# INFO:tensorflow:global_step/sec: 347.936
# INFO:tensorflow:loss = 0.022257674, step = 8400 (0.291 sec)
# INFO:tensorflow:Saving checkpoints for 8500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-8500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:20
# INFO:tensorflow:Saving dict for global step 8500: global_step = 8500, loss = 0.023805765
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8500: rbm_train_dir/model.ckpt-8500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-8500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352080'/saved_model.pb
# INFO:tensorflow:global_step/sec: 35.3487
# INFO:tensorflow:loss = 0.02386141, step = 8500 (2.827 sec)
# INFO:tensorflow:global_step/sec: 337.446
# INFO:tensorflow:loss = 0.02282524, step = 8600 (0.297 sec)
# INFO:tensorflow:global_step/sec: 341.883
# INFO:tensorflow:loss = 0.024105096, step = 8700 (0.290 sec)
# INFO:tensorflow:global_step/sec: 367.876
# INFO:tensorflow:loss = 0.022067042, step = 8800 (0.272 sec)
# INFO:tensorflow:global_step/sec: 368.751
# INFO:tensorflow:loss = 0.024407564, step = 8900 (0.273 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:24
# INFO:tensorflow:Saving dict for global step 9000: global_step = 9000, loss = 0.02347796
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: rbm_train_dir/model.ckpt-9000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-9000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352084'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.9296
# INFO:tensorflow:loss = 0.023433829, step = 9000 (2.636 sec)
# INFO:tensorflow:global_step/sec: 339.576
# INFO:tensorflow:loss = 0.02408555, step = 9100 (0.295 sec)
# INFO:tensorflow:global_step/sec: 367.441
# INFO:tensorflow:loss = 0.02248579, step = 9200 (0.273 sec)
# INFO:tensorflow:global_step/sec: 352.739
# INFO:tensorflow:loss = 0.022723256, step = 9300 (0.282 sec)
# INFO:tensorflow:global_step/sec: 348.107
# INFO:tensorflow:loss = 0.022628374, step = 9400 (0.286 sec)
# INFO:tensorflow:Saving checkpoints for 9500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-9500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:28
# INFO:tensorflow:Saving dict for global step 9500: global_step = 9500, loss = 0.02311093
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9500: rbm_train_dir/model.ckpt-9500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-9500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352088'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.3777
# INFO:tensorflow:loss = 0.022071663, step = 9500 (2.909 sec)
# INFO:tensorflow:global_step/sec: 300.967
# INFO:tensorflow:loss = 0.025231121, step = 9600 (0.349 sec)
# INFO:tensorflow:global_step/sec: 331.913
# INFO:tensorflow:loss = 0.022550453, step = 9700 (0.286 sec)
# INFO:tensorflow:global_step/sec: 350.668
# INFO:tensorflow:loss = 0.022956965, step = 9800 (0.284 sec)
# INFO:tensorflow:global_step/sec: 357.915
# INFO:tensorflow:loss = 0.021873698, step = 9900 (0.281 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:32
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 0.022876143
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: rbm_train_dir/model.ckpt-10000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-10000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352092'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.1902
# INFO:tensorflow:loss = 0.022756526, step = 10000 (2.687 sec)
# INFO:tensorflow:global_step/sec: 372.214
# INFO:tensorflow:loss = 0.022455486, step = 10100 (0.271 sec)
# INFO:tensorflow:global_step/sec: 366.833
# INFO:tensorflow:loss = 0.021959968, step = 10200 (0.272 sec)
# INFO:tensorflow:global_step/sec: 368.844
# INFO:tensorflow:loss = 0.022027388, step = 10300 (0.271 sec)
# INFO:tensorflow:global_step/sec: 374.182
# INFO:tensorflow:loss = 0.023245223, step = 10400 (0.265 sec)
# INFO:tensorflow:Saving checkpoints for 10500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-10500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:36
# INFO:tensorflow:Saving dict for global step 10500: global_step = 10500, loss = 0.02256752
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10500: rbm_train_dir/model.ckpt-10500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-10500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352096'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.3299
# INFO:tensorflow:loss = 0.021953542, step = 10500 (2.681 sec)
# INFO:tensorflow:global_step/sec: 349.994
# INFO:tensorflow:loss = 0.022301322, step = 10600 (0.284 sec)
# INFO:tensorflow:global_step/sec: 369.344
# INFO:tensorflow:loss = 0.024839567, step = 10700 (0.270 sec)
# INFO:tensorflow:global_step/sec: 376.976
# INFO:tensorflow:loss = 0.023423888, step = 10800 (0.266 sec)
# INFO:tensorflow:global_step/sec: 388.28
# INFO:tensorflow:loss = 0.023278154, step = 10900 (0.257 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:40
# INFO:tensorflow:Saving dict for global step 11000: global_step = 11000, loss = 0.022393972
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: rbm_train_dir/model.ckpt-11000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-11000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352100'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.6501
# INFO:tensorflow:loss = 0.021238578, step = 11000 (2.590 sec)
# INFO:tensorflow:global_step/sec: 337.084
# INFO:tensorflow:loss = 0.022150034, step = 11100 (0.295 sec)
# INFO:tensorflow:global_step/sec: 355.053
# INFO:tensorflow:loss = 0.022372078, step = 11200 (0.284 sec)
# INFO:tensorflow:global_step/sec: 377.351
# INFO:tensorflow:loss = 0.021546412, step = 11300 (0.265 sec)
# INFO:tensorflow:global_step/sec: 379.39
# INFO:tensorflow:loss = 0.02269511, step = 11400 (0.262 sec)
# INFO:tensorflow:Saving checkpoints for 11500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:01:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-11500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:01:44
# INFO:tensorflow:Saving dict for global step 11500: global_step = 11500, loss = 0.022137946
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11500: rbm_train_dir/model.ckpt-11500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-11500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352104'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.0099
# INFO:tensorflow:loss = 0.02195321, step = 11500 (2.941 sec)
# INFO:tensorflow:global_step/sec: 265.604
# ...
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-46000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352369'/saved_model.pb
# INFO:tensorflow:global_step/sec: 41.1481
# INFO:tensorflow:loss = 0.015600452, step = 46000 (2.431 sec)
# INFO:tensorflow:global_step/sec: 356.54
# INFO:tensorflow:loss = 0.017068392, step = 46100 (0.283 sec)
# INFO:tensorflow:global_step/sec: 367.539
# INFO:tensorflow:loss = 0.016006114, step = 46200 (0.270 sec)
# INFO:tensorflow:global_step/sec: 379.117
# INFO:tensorflow:loss = 0.017398987, step = 46300 (0.262 sec)
# INFO:tensorflow:global_step/sec: 385.618
# INFO:tensorflow:loss = 0.017152617, step = 46400 (0.263 sec)
# INFO:tensorflow:Saving checkpoints for 46500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-46500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:13
# INFO:tensorflow:Saving dict for global step 46500: global_step = 46500, loss = 0.016933912
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46500: rbm_train_dir/model.ckpt-46500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-46500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352373'/saved_model.pb
# INFO:tensorflow:global_step/sec: 26.7366
# INFO:tensorflow:loss = 0.016439255, step = 46500 (3.738 sec)
# INFO:tensorflow:global_step/sec: 374.385
# INFO:tensorflow:loss = 0.0172159, step = 46600 (0.269 sec)
# INFO:tensorflow:global_step/sec: 372.3
# INFO:tensorflow:loss = 0.016763221, step = 46700 (0.269 sec)
# INFO:tensorflow:global_step/sec: 389.397
# INFO:tensorflow:loss = 0.016958484, step = 46800 (0.254 sec)
# INFO:tensorflow:global_step/sec: 377.915
# INFO:tensorflow:loss = 0.018117161, step = 46900 (0.265 sec)
# INFO:tensorflow:Saving checkpoints for 47000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:17
# INFO:tensorflow:Saving dict for global step 47000: global_step = 47000, loss = 0.016875077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: rbm_train_dir/model.ckpt-47000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-47000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352377'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.3097
# INFO:tensorflow:loss = 0.016048796, step = 47000 (2.612 sec)
# INFO:tensorflow:global_step/sec: 369.387
# INFO:tensorflow:loss = 0.017351942, step = 47100 (0.270 sec)
# INFO:tensorflow:global_step/sec: 342.187
# INFO:tensorflow:loss = 0.01742834, step = 47200 (0.291 sec)
# INFO:tensorflow:global_step/sec: 374.098
# INFO:tensorflow:loss = 0.016024893, step = 47300 (0.269 sec)
# INFO:tensorflow:global_step/sec: 377.144
# INFO:tensorflow:loss = 0.017855717, step = 47400 (0.263 sec)
# INFO:tensorflow:Saving checkpoints for 47500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-47500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:21
# INFO:tensorflow:Saving dict for global step 47500: global_step = 47500, loss = 0.016839553
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47500: rbm_train_dir/model.ckpt-47500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-47500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352381'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.9826
# INFO:tensorflow:loss = 0.017841732, step = 47500 (2.501 sec)
# INFO:tensorflow:global_step/sec: 304.007
# INFO:tensorflow:loss = 0.016110323, step = 47600 (0.330 sec)
# INFO:tensorflow:global_step/sec: 326.25
# INFO:tensorflow:loss = 0.01792627, step = 47700 (0.309 sec)
# INFO:tensorflow:global_step/sec: 335.101
# INFO:tensorflow:loss = 0.01729892, step = 47800 (0.299 sec)
# INFO:tensorflow:global_step/sec: 328.062
# INFO:tensorflow:loss = 0.016844207, step = 47900 (0.304 sec)
# INFO:tensorflow:Saving checkpoints for 48000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:25
# INFO:tensorflow:Saving dict for global step 48000: global_step = 48000, loss = 0.016843071
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: rbm_train_dir/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 42.7366
# INFO:tensorflow:loss = 0.01612339, step = 48000 (2.339 sec)
# INFO:tensorflow:global_step/sec: 326.056
# INFO:tensorflow:loss = 0.016163178, step = 48100 (0.306 sec)
# INFO:tensorflow:global_step/sec: 318.806
# INFO:tensorflow:loss = 0.016888183, step = 48200 (0.316 sec)
# INFO:tensorflow:global_step/sec: 343.275
# INFO:tensorflow:loss = 0.017967544, step = 48300 (0.293 sec)
# INFO:tensorflow:global_step/sec: 356.687
# INFO:tensorflow:loss = 0.016719896, step = 48400 (0.278 sec)
# INFO:tensorflow:Saving checkpoints for 48500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-48500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:29
# INFO:tensorflow:Saving dict for global step 48500: global_step = 48500, loss = 0.01680285
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48500: rbm_train_dir/model.ckpt-48500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-48500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352389'/saved_model.pb
# INFO:tensorflow:global_step/sec: 31.7245
# INFO:tensorflow:loss = 0.01652631, step = 48500 (3.151 sec)
# INFO:tensorflow:global_step/sec: 361.676
# INFO:tensorflow:loss = 0.016422484, step = 48600 (0.278 sec)
# INFO:tensorflow:global_step/sec: 354.517
# INFO:tensorflow:loss = 0.01575219, step = 48700 (0.283 sec)
# INFO:tensorflow:global_step/sec: 347.853
# INFO:tensorflow:loss = 0.015801972, step = 48800 (0.287 sec)
# INFO:tensorflow:global_step/sec: 388.683
# INFO:tensorflow:loss = 0.016324677, step = 48900 (0.256 sec)
# INFO:tensorflow:Saving checkpoints for 49000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:33
# INFO:tensorflow:Saving dict for global step 49000: global_step = 49000, loss = 0.016763875
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: rbm_train_dir/model.ckpt-49000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-49000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352393'/saved_model.pb
# INFO:tensorflow:global_step/sec: 36.8318
# INFO:tensorflow:loss = 0.01677671, step = 49000 (2.714 sec)
# INFO:tensorflow:global_step/sec: 334.041
# INFO:tensorflow:loss = 0.016963985, step = 49100 (0.302 sec)
# INFO:tensorflow:global_step/sec: 338.146
# INFO:tensorflow:loss = 0.015310479, step = 49200 (0.296 sec)
# INFO:tensorflow:global_step/sec: 371.76
# INFO:tensorflow:loss = 0.016560787, step = 49300 (0.266 sec)
# INFO:tensorflow:global_step/sec: 364.832
# INFO:tensorflow:loss = 0.016633699, step = 49400 (0.274 sec)
# INFO:tensorflow:Saving checkpoints for 49500 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:36Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-49500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:37
# INFO:tensorflow:Saving dict for global step 49500: global_step = 49500, loss = 0.016729219
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49500: rbm_train_dir/model.ckpt-49500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-49500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352397'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.1826
# INFO:tensorflow:loss = 0.01579864, step = 49500 (2.554 sec)
# INFO:tensorflow:global_step/sec: 336.746
# INFO:tensorflow:loss = 0.016354432, step = 49600 (0.296 sec)
# INFO:tensorflow:global_step/sec: 346.992
# INFO:tensorflow:loss = 0.017308788, step = 49700 (0.288 sec)
# INFO:tensorflow:global_step/sec: 384.951
# INFO:tensorflow:loss = 0.016704114, step = 49800 (0.262 sec)
# INFO:tensorflow:global_step/sec: 361.367
# INFO:tensorflow:loss = 0.0173152, step = 49900 (0.277 sec)
# INFO:tensorflow:Saving checkpoints for 50000 into rbm_train_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:06:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:06:40
# INFO:tensorflow:Saving dict for global step 50000: global_step = 50000, loss = 0.016702455
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: rbm_train_dir/model.ckpt-50000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from rbm_train_dir/model.ckpt-50000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: rbm_train_dir/export/best_rbm/temp-b'1556352400'/saved_model.pb
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Loss for final step: 0.016108293.
# ({'global_step': 50000, 'loss': 0.016702455},
#  [b'rbm_train_dir/export/best_rbm/1556352400'])

# %%
BATCH_SIZE = 100 #@param {type:"integer"}
EPOCHS = 100 #@param {type:"integer"}
L_RATE = 0.01 #@param {type:'number'}
MOMENTUM = 0.9 #@param {type:"number"}
DEC_RATE = 0.99 #@param {type:"number"}
model_dir = "belief_net_dir" #@param {type:"string"}
checkpoint = 'rbm_train_dir/model.ckpt-50000'
steps_per_epoch = 50000 // BATCH_SIZE

run_config = tf.estimator.RunConfig(save_summary_steps=10,
                                    save_checkpoints_steps=steps_per_epoch,
                                    experimental_distribute=distribute)
# Out:
# INFO:tensorflow:Initializing RunConfig with distribution strategies.
# INFO:tensorflow:Not using Distribute Coordinator.

# %% [markdown]
# # Belief Network model_fn
# Implementation of the belief network with the trained RBM.

# %%
def belief_net_inference(input_):
    
    v_input = tf.cast(input_['image'], dtype=tf.float32)
    
    with tf.variable_scope('rbm', reuse=tf.AUTO_REUSE):
        weights = tf.get_variable(name='weights',
                                  shape=(784, HIDDEN_NEURONS),
                                  initializer=tf.keras.initializers.RandomNormal(stddev=0.01, dtype=tf.float32),
                                  trainable=True)
        h_bias = tf.get_variable(name='bias',
                                 shape=(1, HIDDEN_NEURONS),
                                 initializer=tf.keras.initializers.Zeros(dtype=tf.float32),
                                 trainable=True)

    h_act = tf.math.sigmoid((v_input @ weights) + h_bias)
    
    with tf.variable_scope('softmax'):
        logits = tf.layers.Dense(units=N_CLASSES)(h_act)

    return logits

# %%
def belief_net_model_fn(features, labels=None, mode=None, params=None):    
    
    logits = belief_net_inference(features)
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        cross_entropy = tf.losses.softmax_cross_entropy(tf.one_hot(labels, N_CLASSES), logits=logits)
        lr = tf.train.exponential_decay(learning_rate=L_RATE,
                                        global_step=tf.train.get_or_create_global_step(),
                                        decay_steps=steps_per_epoch,
                                        decay_rate=DEC_RATE,
                                        staircase=True)
        
        nn_opt = tf.train.MomentumOptimizer(learning_rate=lr, momentum=MOMENTUM)
        nn_train_op = nn_opt.minimize(loss=cross_entropy,
                                      global_step=tf.train.get_or_create_global_step(),
                                      var_list=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,
                                                                 scope='softmax'))

        accuracy = tf.metrics.accuracy(labels=tf.cast(labels, tf.int32),
                                       predictions=tf.argmax(logits, axis=1),
                                       name='accuracy')
        eval_metric = {
            'accuracy': accuracy
        }
        return tf.estimator.EstimatorSpec(mode=tf.estimator.ModeKeys.TRAIN,
                                          loss=cross_entropy,
                                          train_op=nn_train_op,
                                          eval_metric_ops=eval_metric)
    
    predictions = {'classes': tf.argmax(logits),
                   'probabilities': tf.nn.softmax(logits)
                  }
    if mode == tf.estimator.ModeKeys.PREDICT:
        export_outputs = {
            'predict_output': tf.estimator.export.PredictOutput(predictions)
        }
        return tf.estimator.EstimatorSpec(mode=tf.estimator.ModeKeys.PREDICT,
                                          predictions=predictions,
                                          export_outputs=export_outputs)

    if mode == tf.estimator.ModeKeys.EVAL:
        cross_entropy = tf.losses.softmax_cross_entropy(tf.one_hot(labels, N_CLASSES), logits=logits)
        accuracy = tf.metrics.accuracy(labels=tf.cast(labels, tf.int32),
                                       predictions=tf.argmax(logits, axis=1),
                                       name='accuracy')
        eval_metric = {
            'accuracy': accuracy
        }
        return tf.estimator.EstimatorSpec(mode=mode,
                                          predictions=predictions,
                                          loss=cross_entropy,
                                          eval_metric_ops=eval_metric)

# %%
ws = tf.estimator.WarmStartSettings(ckpt_to_initialize_from=checkpoint,
                                    vars_to_warm_start=["rbm/weights", "rbm/bias"])

bn_estimator = tf.estimator.Estimator(model_fn=belief_net_model_fn,
                                      model_dir=model_dir,
                                      config=run_config,
                                      params={},
                                      warm_start_from=ws)
os.makedirs(bn_estimator.eval_dir())


exporter = tf.estimator.BestExporter(name="best_model",
                                     serving_input_receiver_fn=serving_input_rec_fn,
                                     exports_to_keep=3)

early_stopping = tf.contrib.estimator.stop_if_no_decrease_hook(estimator=bn_estimator,
                                                               metric_name='loss',
                                                               max_steps_without_decrease=5,
                                                               min_steps=5)

train_spec = tf.estimator.TrainSpec(input_fn=data_input_fn(tr_img, tr_lab, phase='train'),
                                    max_steps=EPOCHS * steps_per_epoch,
                                    hooks=[early_stopping])

eval_spec = tf.estimator.EvalSpec(input_fn=data_input_fn(eval_img, eval_lab, phase='eval'),
                                  steps=1,
                                  name='Validation',
                                  hooks=None,
                                  exporters=[exporter],
                                  start_delay_secs=0,
                                  throttle_secs=0)

tf.estimator.train_and_evaluate(estimator=bn_estimator,
                                train_spec=train_spec,
                                eval_spec=eval_spec)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'belief_net_dir', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': <tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2e1c596a0>, '_device_fn': None, '_protocol': None, '_eval_distribute': <tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2e1c597f0>, '_experimental_distribute': DistributeConfig(train_distribute=<tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2e1c596a0>, eval_distribute=<tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2e1c597f0>, remote_cluster=None), '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc2e1c59978>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 500 or save_checkpoints_secs None.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py:1419: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='rbm_train_dir/model.ckpt-50000', vars_to_warm_start=['rbm/weights', 'rbm/bias'], var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ('rbm_train_dir/model.ckpt-50000',)
# INFO:tensorflow:Warm-starting variable: rbm/weights; prev_var_name: Unchanged
# INFO:tensorflow:Warm-starting variable: rbm/bias; prev_var_name: Unchanged
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:loss = 2.5466228, step = 0
# INFO:tensorflow:global_step/sec: 421.42
# INFO:tensorflow:loss = 1.1919976, step = 100 (0.241 sec)
# INFO:tensorflow:global_step/sec: 467.567
# INFO:tensorflow:loss = 0.7297039, step = 200 (0.214 sec)
# INFO:tensorflow:global_step/sec: 443.764
# INFO:tensorflow:loss = 0.5982758, step = 300 (0.227 sec)
# INFO:tensorflow:global_step/sec: 456.604
# INFO:tensorflow:loss = 0.5233639, step = 400 (0.215 sec)
# INFO:tensorflow:Saving checkpoints for 500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:42:43Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:42:43
# INFO:tensorflow:Saving dict for global step 500: accuracy = 0.8743333, global_step = 500, loss = 0.50222623
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: belief_net_dir/model.ckpt-500
# INFO:tensorflow:Loading best metric from event files.
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:205: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354564'/saved_model.pb
# INFO:tensorflow:global_step/sec: 27.0848
# INFO:tensorflow:loss = 0.5008612, step = 500 (3.693 sec)
# INFO:tensorflow:global_step/sec: 443.215
# INFO:tensorflow:loss = 0.51327074, step = 600 (0.228 sec)
# INFO:tensorflow:global_step/sec: 424.65
# INFO:tensorflow:loss = 0.47443372, step = 700 (0.234 sec)
# INFO:tensorflow:global_step/sec: 462.116
# INFO:tensorflow:loss = 0.44376716, step = 800 (0.215 sec)
# INFO:tensorflow:global_step/sec: 436.666
# INFO:tensorflow:loss = 0.5026168, step = 900 (0.230 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:42:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:42:47
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.88883334, global_step = 1000, loss = 0.41110963
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: belief_net_dir/model.ckpt-1000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354567'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.5673
# INFO:tensorflow:loss = 0.3905375, step = 1000 (2.659 sec)
# INFO:tensorflow:global_step/sec: 432.852
# INFO:tensorflow:loss = 0.3703732, step = 1100 (0.234 sec)
# INFO:tensorflow:global_step/sec: 460.638
# INFO:tensorflow:loss = 0.33706295, step = 1200 (0.217 sec)
# INFO:tensorflow:global_step/sec: 461.264
# INFO:tensorflow:loss = 0.41404298, step = 1300 (0.215 sec)
# INFO:tensorflow:global_step/sec: 471.202
# INFO:tensorflow:loss = 0.32637432, step = 1400 (0.214 sec)
# INFO:tensorflow:Saving checkpoints for 1500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:42:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:42:51
# INFO:tensorflow:Saving dict for global step 1500: accuracy = 0.89683336, global_step = 1500, loss = 0.37335438
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1500: belief_net_dir/model.ckpt-1500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-1500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354571'/saved_model.pb
# INFO:tensorflow:global_step/sec: 31.9522
# INFO:tensorflow:loss = 0.25381044, step = 1500 (3.127 sec)
# INFO:tensorflow:global_step/sec: 441.671
# INFO:tensorflow:loss = 0.39001435, step = 1600 (0.229 sec)
# INFO:tensorflow:global_step/sec: 448.644
# INFO:tensorflow:loss = 0.30151767, step = 1700 (0.223 sec)
# INFO:tensorflow:global_step/sec: 465.341
# INFO:tensorflow:loss = 0.230547, step = 1800 (0.215 sec)
# INFO:tensorflow:global_step/sec: 455.9
# INFO:tensorflow:loss = 0.32039112, step = 1900 (0.217 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:42:55Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:42:55
# INFO:tensorflow:Saving dict for global step 2000: accuracy = 0.9005, global_step = 2000, loss = 0.35414198
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: belief_net_dir/model.ckpt-2000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-2000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354575'/saved_model.pb
# INFO:tensorflow:global_step/sec: 31.5297
# INFO:tensorflow:loss = 0.38256472, step = 2000 (3.172 sec)
# INFO:tensorflow:global_step/sec: 380.935
# INFO:tensorflow:loss = 0.23496374, step = 2100 (0.263 sec)
# INFO:tensorflow:global_step/sec: 363.744
# INFO:tensorflow:loss = 0.37504426, step = 2200 (0.278 sec)
# INFO:tensorflow:global_step/sec: 381.2
# INFO:tensorflow:loss = 0.3227062, step = 2300 (0.262 sec)
# INFO:tensorflow:global_step/sec: 415.985
# INFO:tensorflow:loss = 0.3104102, step = 2400 (0.238 sec)
# INFO:tensorflow:Saving checkpoints for 2500 into belief_net_dir/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:42:58Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-2500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:42:59
# INFO:tensorflow:Saving dict for global step 2500: accuracy = 0.9033333, global_step = 2500, loss = 0.34059286
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2500: belief_net_dir/model.ckpt-2500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-2500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354579'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.6565
# INFO:tensorflow:loss = 0.3175979, step = 2500 (2.884 sec)
# INFO:tensorflow:global_step/sec: 408.2
# INFO:tensorflow:loss = 0.37814507, step = 2600 (0.248 sec)
# INFO:tensorflow:global_step/sec: 416.032
# INFO:tensorflow:loss = 0.2653816, step = 2700 (0.239 sec)
# INFO:tensorflow:global_step/sec: 418.472
# INFO:tensorflow:loss = 0.3696949, step = 2800 (0.240 sec)
# INFO:tensorflow:global_step/sec: 399.363
# INFO:tensorflow:loss = 0.34334698, step = 2900 (0.251 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:03
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.906, global_step = 3000, loss = 0.33016127
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: belief_net_dir/model.ckpt-3000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-3000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354583'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.9163
# INFO:tensorflow:loss = 0.45340016, step = 3000 (2.634 sec)
# INFO:tensorflow:global_step/sec: 433.769
# INFO:tensorflow:loss = 0.30630162, step = 3100 (0.232 sec)
# INFO:tensorflow:global_step/sec: 463.308
# INFO:tensorflow:loss = 0.23351492, step = 3200 (0.217 sec)
# INFO:tensorflow:global_step/sec: 462.844
# INFO:tensorflow:loss = 0.34255645, step = 3300 (0.214 sec)
# INFO:tensorflow:global_step/sec: 471.1
# INFO:tensorflow:loss = 0.38683334, step = 3400 (0.214 sec)
# INFO:tensorflow:Saving checkpoints for 3500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-3500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:07
# INFO:tensorflow:Saving dict for global step 3500: accuracy = 0.9086667, global_step = 3500, loss = 0.322483
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3500: belief_net_dir/model.ckpt-3500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-3500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354587'/saved_model.pb
# INFO:tensorflow:global_step/sec: 32.4238
# INFO:tensorflow:loss = 0.2429535, step = 3500 (3.083 sec)
# INFO:tensorflow:global_step/sec: 452.49
# INFO:tensorflow:loss = 0.27816546, step = 3600 (0.222 sec)
# INFO:tensorflow:global_step/sec: 411.044
# INFO:tensorflow:loss = 0.25249797, step = 3700 (0.244 sec)
# INFO:tensorflow:global_step/sec: 449.608
# INFO:tensorflow:loss = 0.36817357, step = 3800 (0.221 sec)
# INFO:tensorflow:global_step/sec: 444.694
# INFO:tensorflow:loss = 0.24759898, step = 3900 (0.224 sec)
# INFO:tensorflow:Saving checkpoints for 4000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:10Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:10
# INFO:tensorflow:Saving dict for global step 4000: accuracy = 0.91, global_step = 4000, loss = 0.31641304
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: belief_net_dir/model.ckpt-4000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-4000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354590'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.3904
# INFO:tensorflow:loss = 0.2000552, step = 4000 (2.538 sec)
# INFO:tensorflow:global_step/sec: 426.492
# INFO:tensorflow:loss = 0.38595855, step = 4100 (0.234 sec)
# INFO:tensorflow:global_step/sec: 404.01
# INFO:tensorflow:loss = 0.33094987, step = 4200 (0.250 sec)
# INFO:tensorflow:global_step/sec: 452.054
# INFO:tensorflow:loss = 0.20212726, step = 4300 (0.219 sec)
# INFO:tensorflow:global_step/sec: 471.922
# INFO:tensorflow:loss = 0.16380557, step = 4400 (0.211 sec)
# INFO:tensorflow:Saving checkpoints for 4500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-4500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:14
# INFO:tensorflow:Saving dict for global step 4500: accuracy = 0.91116667, global_step = 4500, loss = 0.31146905
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4500: belief_net_dir/model.ckpt-4500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-4500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354594'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.2402
# INFO:tensorflow:loss = 0.28088683, step = 4500 (2.685 sec)
# INFO:tensorflow:global_step/sec: 427.623
# INFO:tensorflow:loss = 0.28304145, step = 4600 (0.235 sec)
# INFO:tensorflow:global_step/sec: 447.76
# INFO:tensorflow:loss = 0.22299118, step = 4700 (0.225 sec)
# INFO:tensorflow:global_step/sec: 421.205
# INFO:tensorflow:loss = 0.40951088, step = 4800 (0.238 sec)
# INFO:tensorflow:global_step/sec: 453.677
# INFO:tensorflow:loss = 0.23169236, step = 4900 (0.219 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:18
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.91283333, global_step = 5000, loss = 0.307711
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: belief_net_dir/model.ckpt-5000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-5000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354598'/saved_model.pb
# INFO:tensorflow:global_step/sec: 33.811
# INFO:tensorflow:loss = 0.2745281, step = 5000 (2.958 sec)
# INFO:tensorflow:global_step/sec: 416.149
# INFO:tensorflow:loss = 0.22682327, step = 5100 (0.239 sec)
# INFO:tensorflow:global_step/sec: 437.084
# INFO:tensorflow:loss = 0.26895753, step = 5200 (0.229 sec)
# INFO:tensorflow:global_step/sec: 454.425
# INFO:tensorflow:loss = 0.2510598, step = 5300 (0.221 sec)
# INFO:tensorflow:global_step/sec: 441.828
# INFO:tensorflow:loss = 0.21887779, step = 5400 (0.227 sec)
# INFO:tensorflow:Saving checkpoints for 5500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-5500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:21
# INFO:tensorflow:Saving dict for global step 5500: accuracy = 0.91316664, global_step = 5500, loss = 0.30466548
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5500: belief_net_dir/model.ckpt-5500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-5500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354601'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.5144
# INFO:tensorflow:loss = 0.17083496, step = 5500 (2.531 sec)
# INFO:tensorflow:global_step/sec: 416.612
# INFO:tensorflow:loss = 0.35089353, step = 5600 (0.241 sec)
# INFO:tensorflow:global_step/sec: 444.66
# INFO:tensorflow:loss = 0.264699, step = 5700 (0.222 sec)
# INFO:tensorflow:global_step/sec: 449.91
# INFO:tensorflow:loss = 0.3424189, step = 5800 (0.225 sec)
# INFO:tensorflow:global_step/sec: 455.196
# INFO:tensorflow:loss = 0.35399643, step = 5900 (0.220 sec)
# INFO:tensorflow:Saving checkpoints for 6000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:25
# INFO:tensorflow:Saving dict for global step 6000: accuracy = 0.91333336, global_step = 6000, loss = 0.30128342
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: belief_net_dir/model.ckpt-6000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-6000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354605'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.2894
# INFO:tensorflow:loss = 0.29497394, step = 6000 (2.680 sec)
# INFO:tensorflow:global_step/sec: 418.728
# INFO:tensorflow:loss = 0.29710293, step = 6100 (0.241 sec)
# INFO:tensorflow:global_step/sec: 434.954
# INFO:tensorflow:loss = 0.22211304, step = 6200 (0.230 sec)
# INFO:tensorflow:global_step/sec: 465.757
# INFO:tensorflow:loss = 0.42679352, step = 6300 (0.215 sec)
# INFO:tensorflow:global_step/sec: 454.319
# INFO:tensorflow:loss = 0.23375499, step = 6400 (0.219 sec)
# INFO:tensorflow:Saving checkpoints for 6500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:28Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-6500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:29
# INFO:tensorflow:Saving dict for global step 6500: accuracy = 0.91316664, global_step = 6500, loss = 0.29897845
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6500: belief_net_dir/model.ckpt-6500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-6500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354609'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.1422
# INFO:tensorflow:loss = 0.2566662, step = 6500 (2.929 sec)
# INFO:tensorflow:global_step/sec: 470.61
# INFO:tensorflow:loss = 0.34619057, step = 6600 (0.214 sec)
# INFO:tensorflow:global_step/sec: 469.11
# INFO:tensorflow:loss = 0.31556377, step = 6700 (0.213 sec)
# INFO:tensorflow:global_step/sec: 442.199
# INFO:tensorflow:loss = 0.18636551, step = 6800 (0.225 sec)
# INFO:tensorflow:global_step/sec: 472.063
# INFO:tensorflow:loss = 0.19048157, step = 6900 (0.212 sec)
# INFO:tensorflow:Saving checkpoints for 7000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:32Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:32
# INFO:tensorflow:Saving dict for global step 7000: accuracy = 0.915, global_step = 7000, loss = 0.29637077
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: belief_net_dir/model.ckpt-7000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-7000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354612'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.2143
# INFO:tensorflow:loss = 0.16177212, step = 7000 (2.922 sec)
# INFO:tensorflow:global_step/sec: 411.816
# INFO:tensorflow:loss = 0.35624608, step = 7100 (0.244 sec)
# INFO:tensorflow:global_step/sec: 423.761
# INFO:tensorflow:loss = 0.17875262, step = 7200 (0.235 sec)
# INFO:tensorflow:global_step/sec: 449.785
# INFO:tensorflow:loss = 0.26785946, step = 7300 (0.223 sec)
# INFO:tensorflow:global_step/sec: 444.824
# INFO:tensorflow:loss = 0.42214695, step = 7400 (0.223 sec)
# INFO:tensorflow:Saving checkpoints for 7500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-7500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:36
# INFO:tensorflow:Saving dict for global step 7500: accuracy = 0.91583335, global_step = 7500, loss = 0.2940805
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7500: belief_net_dir/model.ckpt-7500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-7500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354616'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.2128
# INFO:tensorflow:loss = 0.13090959, step = 7500 (2.618 sec)
# INFO:tensorflow:global_step/sec: 437.606
# INFO:tensorflow:loss = 0.30702072, step = 7600 (0.230 sec)
# INFO:tensorflow:global_step/sec: 467.097
# INFO:tensorflow:loss = 0.2429516, step = 7700 (0.214 sec)
# INFO:tensorflow:global_step/sec: 470.937
# INFO:tensorflow:loss = 0.23645787, step = 7800 (0.212 sec)
# INFO:tensorflow:global_step/sec: 460.688
# INFO:tensorflow:loss = 0.26996723, step = 7900 (0.215 sec)
# INFO:tensorflow:Saving checkpoints for 8000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:39Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:39
# INFO:tensorflow:Saving dict for global step 8000: accuracy = 0.91616666, global_step = 8000, loss = 0.29260042
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: belief_net_dir/model.ckpt-8000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-8000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354619'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.2494
# INFO:tensorflow:loss = 0.45169038, step = 8000 (2.613 sec)
# INFO:tensorflow:global_step/sec: 448.905
# INFO:tensorflow:loss = 0.27254674, step = 8100 (0.226 sec)
# INFO:tensorflow:global_step/sec: 453.565
# INFO:tensorflow:loss = 0.2430439, step = 8200 (0.218 sec)
# INFO:tensorflow:global_step/sec: 446.218
# INFO:tensorflow:loss = 0.33277747, step = 8300 (0.225 sec)
# INFO:tensorflow:global_step/sec: 453.617
# INFO:tensorflow:loss = 0.2281877, step = 8400 (0.222 sec)
# INFO:tensorflow:Saving checkpoints for 8500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-8500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:43
# INFO:tensorflow:Saving dict for global step 8500: accuracy = 0.91566664, global_step = 8500, loss = 0.29165658
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8500: belief_net_dir/model.ckpt-8500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-8500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354623'/saved_model.pb
# INFO:tensorflow:global_step/sec: 32.3629
# INFO:tensorflow:loss = 0.28807434, step = 8500 (3.089 sec)
# INFO:tensorflow:global_step/sec: 365.841
# INFO:tensorflow:loss = 0.38026452, step = 8600 (0.272 sec)
# INFO:tensorflow:global_step/sec: 435.682
# INFO:tensorflow:loss = 0.26842925, step = 8700 (0.230 sec)
# INFO:tensorflow:global_step/sec: 454.521
# INFO:tensorflow:loss = 0.32536933, step = 8800 (0.224 sec)
# INFO:tensorflow:global_step/sec: 446.042
# INFO:tensorflow:loss = 0.46651334, step = 8900 (0.221 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:46Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:47
# INFO:tensorflow:Saving dict for global step 9000: accuracy = 0.916, global_step = 9000, loss = 0.2899258
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: belief_net_dir/model.ckpt-9000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-9000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354627'/saved_model.pb
# INFO:tensorflow:global_step/sec: 37.5159
# INFO:tensorflow:loss = 0.26691598, step = 9000 (2.666 sec)
# INFO:tensorflow:global_step/sec: 437.758
# INFO:tensorflow:loss = 0.27467346, step = 9100 (0.230 sec)
# INFO:tensorflow:global_step/sec: 435.612
# INFO:tensorflow:loss = 0.23358722, step = 9200 (0.227 sec)
# INFO:tensorflow:global_step/sec: 443.894
# INFO:tensorflow:loss = 0.20151341, step = 9300 (0.228 sec)
# INFO:tensorflow:global_step/sec: 465.361
# INFO:tensorflow:loss = 0.26103103, step = 9400 (0.214 sec)
# INFO:tensorflow:Saving checkpoints for 9500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:50Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-9500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:50
# INFO:tensorflow:Saving dict for global step 9500: accuracy = 0.91716665, global_step = 9500, loss = 0.28852668
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9500: belief_net_dir/model.ckpt-9500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-9500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354630'/saved_model.pb
# INFO:tensorflow:global_step/sec: 36.0847
# INFO:tensorflow:loss = 0.18251319, step = 9500 (2.770 sec)
# INFO:tensorflow:global_step/sec: 461.411
# INFO:tensorflow:loss = 0.1786467, step = 9600 (0.218 sec)
# INFO:tensorflow:global_step/sec: 470.197
# INFO:tensorflow:loss = 0.30714238, step = 9700 (0.211 sec)
# INFO:tensorflow:global_step/sec: 460.594
# INFO:tensorflow:loss = 0.24128497, step = 9800 (0.219 sec)
# INFO:tensorflow:global_step/sec: 446.021
# INFO:tensorflow:loss = 0.3583077, step = 9900 (0.222 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:54
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.91816664, global_step = 10000, loss = 0.28726786
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: belief_net_dir/model.ckpt-10000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-10000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354634'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.175
# INFO:tensorflow:loss = 0.15872644, step = 10000 (2.927 sec)
# INFO:tensorflow:global_step/sec: 414.857
# INFO:tensorflow:loss = 0.31247836, step = 10100 (0.240 sec)
# INFO:tensorflow:global_step/sec: 421.98
# INFO:tensorflow:loss = 0.23870638, step = 10200 (0.240 sec)
# INFO:tensorflow:global_step/sec: 448.522
# INFO:tensorflow:loss = 0.20423977, step = 10300 (0.220 sec)
# INFO:tensorflow:global_step/sec: 455.911
# INFO:tensorflow:loss = 0.27659303, step = 10400 (0.222 sec)
# INFO:tensorflow:Saving checkpoints for 10500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:43:57Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-10500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:43:58
# INFO:tensorflow:Saving dict for global step 10500: accuracy = 0.9188333, global_step = 10500, loss = 0.2864761
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10500: belief_net_dir/model.ckpt-10500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-10500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354638'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.6842
# INFO:tensorflow:loss = 0.18451929, step = 10500 (2.517 sec)
# INFO:tensorflow:global_step/sec: 416.487
# INFO:tensorflow:loss = 0.39326534, step = 10600 (0.243 sec)
# INFO:tensorflow:global_step/sec: 458.354
# INFO:tensorflow:loss = 0.2045271, step = 10700 (0.218 sec)
# INFO:tensorflow:global_step/sec: 471.601
# INFO:tensorflow:loss = 0.22909805, step = 10800 (0.212 sec)
# INFO:tensorflow:global_step/sec: 446.394
# INFO:tensorflow:loss = 0.2851256, step = 10900 (0.222 sec)
# INFO:tensorflow:Saving checkpoints for 11000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:44:01Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:44:01
# INFO:tensorflow:Saving dict for global step 11000: accuracy = 0.9185, global_step = 11000, loss = 0.28469294
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: belief_net_dir/model.ckpt-11000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-11000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# ...
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-45500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354898'/saved_model.pb
# INFO:tensorflow:global_step/sec: 34.1017
# INFO:tensorflow:loss = 0.16951732, step = 45500 (2.933 sec)
# INFO:tensorflow:global_step/sec: 399.327
# INFO:tensorflow:loss = 0.24419473, step = 45600 (0.249 sec)
# INFO:tensorflow:global_step/sec: 401.451
# INFO:tensorflow:loss = 0.32801262, step = 45700 (0.249 sec)
# INFO:tensorflow:global_step/sec: 398.783
# INFO:tensorflow:loss = 0.36669886, step = 45800 (0.253 sec)
# INFO:tensorflow:global_step/sec: 399.028
# INFO:tensorflow:loss = 0.22265399, step = 45900 (0.251 sec)
# INFO:tensorflow:Saving checkpoints for 46000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-46000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:22
# INFO:tensorflow:Saving dict for global step 46000: accuracy = 0.9225, global_step = 46000, loss = 0.26820204
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46000: belief_net_dir/model.ckpt-46000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-46000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354902'/saved_model.pb
# INFO:tensorflow:global_step/sec: 33.7305
# INFO:tensorflow:loss = 0.32725045, step = 46000 (2.962 sec)
# INFO:tensorflow:global_step/sec: 354.132
# INFO:tensorflow:loss = 0.2685482, step = 46100 (0.282 sec)
# INFO:tensorflow:global_step/sec: 373.338
# INFO:tensorflow:loss = 0.18802962, step = 46200 (0.271 sec)
# INFO:tensorflow:global_step/sec: 398.099
# INFO:tensorflow:loss = 0.18584287, step = 46300 (0.250 sec)
# INFO:tensorflow:global_step/sec: 405.36
# INFO:tensorflow:loss = 0.21611133, step = 46400 (0.248 sec)
# INFO:tensorflow:Saving checkpoints for 46500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-46500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:26
# INFO:tensorflow:Saving dict for global step 46500: accuracy = 0.9225, global_step = 46500, loss = 0.2681694
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46500: belief_net_dir/model.ckpt-46500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-46500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354906'/saved_model.pb
# INFO:tensorflow:global_step/sec: 36.8833
# INFO:tensorflow:loss = 0.15003313, step = 46500 (2.709 sec)
# INFO:tensorflow:global_step/sec: 450.871
# INFO:tensorflow:loss = 0.23062325, step = 46600 (0.224 sec)
# INFO:tensorflow:global_step/sec: 437.756
# INFO:tensorflow:loss = 0.16199659, step = 46700 (0.228 sec)
# INFO:tensorflow:global_step/sec: 480.517
# INFO:tensorflow:loss = 0.23006934, step = 46800 (0.209 sec)
# INFO:tensorflow:global_step/sec: 455.136
# INFO:tensorflow:loss = 0.3381308, step = 46900 (0.219 sec)
# INFO:tensorflow:Saving checkpoints for 47000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:29Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:29
# INFO:tensorflow:Saving dict for global step 47000: accuracy = 0.9228333, global_step = 47000, loss = 0.26798534
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: belief_net_dir/model.ckpt-47000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-47000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354909'/saved_model.pb
# INFO:tensorflow:global_step/sec: 39.4616
# INFO:tensorflow:loss = 0.18569468, step = 47000 (2.532 sec)
# INFO:tensorflow:global_step/sec: 442.719
# INFO:tensorflow:loss = 0.3843103, step = 47100 (0.229 sec)
# INFO:tensorflow:global_step/sec: 453.366
# INFO:tensorflow:loss = 0.18684267, step = 47200 (0.217 sec)
# INFO:tensorflow:global_step/sec: 464.781
# INFO:tensorflow:loss = 0.30868927, step = 47300 (0.218 sec)
# INFO:tensorflow:global_step/sec: 459.305
# INFO:tensorflow:loss = 0.27742207, step = 47400 (0.215 sec)
# INFO:tensorflow:Saving checkpoints for 47500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:33Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-47500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:33
# INFO:tensorflow:Saving dict for global step 47500: accuracy = 0.9231667, global_step = 47500, loss = 0.2681687
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47500: belief_net_dir/model.ckpt-47500
# INFO:tensorflow:global_step/sec: 32.845
# INFO:tensorflow:loss = 0.19891474, step = 47500 (3.045 sec)
# INFO:tensorflow:global_step/sec: 455.85
# INFO:tensorflow:loss = 0.3283929, step = 47600 (0.219 sec)
# INFO:tensorflow:global_step/sec: 451.846
# INFO:tensorflow:loss = 0.17116731, step = 47700 (0.225 sec)
# INFO:tensorflow:global_step/sec: 392.317
# INFO:tensorflow:loss = 0.2674228, step = 47800 (0.252 sec)
# INFO:tensorflow:global_step/sec: 460.483
# INFO:tensorflow:loss = 0.14682302, step = 47900 (0.219 sec)
# INFO:tensorflow:Saving checkpoints for 48000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:36Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:37
# INFO:tensorflow:Saving dict for global step 48000: accuracy = 0.9225, global_step = 48000, loss = 0.26817656
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: belief_net_dir/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 36.0412
# INFO:tensorflow:loss = 0.1888093, step = 48000 (2.772 sec)
# INFO:tensorflow:global_step/sec: 435.976
# INFO:tensorflow:loss = 0.17692465, step = 48100 (0.233 sec)
# INFO:tensorflow:global_step/sec: 440.523
# INFO:tensorflow:loss = 0.24283318, step = 48200 (0.225 sec)
# INFO:tensorflow:global_step/sec: 434.856
# INFO:tensorflow:loss = 0.15632322, step = 48300 (0.228 sec)
# INFO:tensorflow:global_step/sec: 427.743
# INFO:tensorflow:loss = 0.18019015, step = 48400 (0.236 sec)
# INFO:tensorflow:Saving checkpoints for 48500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-48500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:40
# INFO:tensorflow:Saving dict for global step 48500: accuracy = 0.92183334, global_step = 48500, loss = 0.26812088
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48500: belief_net_dir/model.ckpt-48500
# INFO:tensorflow:global_step/sec: 43.2894
# INFO:tensorflow:loss = 0.15767114, step = 48500 (2.308 sec)
# INFO:tensorflow:global_step/sec: 437.132
# INFO:tensorflow:loss = 0.14836884, step = 48600 (0.232 sec)
# INFO:tensorflow:global_step/sec: 427.56
# INFO:tensorflow:loss = 0.19383019, step = 48700 (0.233 sec)
# INFO:tensorflow:global_step/sec: 449.907
# INFO:tensorflow:loss = 0.18973066, step = 48800 (0.223 sec)
# INFO:tensorflow:global_step/sec: 435.75
# INFO:tensorflow:loss = 0.35152063, step = 48900 (0.229 sec)
# INFO:tensorflow:Saving checkpoints for 49000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:44
# INFO:tensorflow:Saving dict for global step 49000: accuracy = 0.92183334, global_step = 49000, loss = 0.2680944
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: belief_net_dir/model.ckpt-49000
# INFO:tensorflow:global_step/sec: 28.9392
# INFO:tensorflow:loss = 0.14717516, step = 49000 (3.453 sec)
# INFO:tensorflow:global_step/sec: 457.558
# INFO:tensorflow:loss = 0.1730654, step = 49100 (0.218 sec)
# INFO:tensorflow:global_step/sec: 458.706
# INFO:tensorflow:loss = 0.2024663, step = 49200 (0.221 sec)
# INFO:tensorflow:global_step/sec: 456.826
# INFO:tensorflow:loss = 0.21478204, step = 49300 (0.217 sec)
# INFO:tensorflow:global_step/sec: 426.566
# INFO:tensorflow:loss = 0.19300698, step = 49400 (0.236 sec)
# INFO:tensorflow:Saving checkpoints for 49500 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-49500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:48
# INFO:tensorflow:Saving dict for global step 49500: accuracy = 0.922, global_step = 49500, loss = 0.2678909
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49500: belief_net_dir/model.ckpt-49500
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-49500
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354928'/saved_model.pb
# INFO:tensorflow:global_step/sec: 38.2838
# INFO:tensorflow:loss = 0.16805656, step = 49500 (2.610 sec)
# INFO:tensorflow:global_step/sec: 428.497
# INFO:tensorflow:loss = 0.22153121, step = 49600 (0.235 sec)
# INFO:tensorflow:global_step/sec: 435.57
# INFO:tensorflow:loss = 0.23148891, step = 49700 (0.231 sec)
# INFO:tensorflow:global_step/sec: 450.374
# INFO:tensorflow:loss = 0.23205411, step = 49800 (0.221 sec)
# INFO:tensorflow:global_step/sec: 463.004
# INFO:tensorflow:loss = 0.16720518, step = 49900 (0.217 sec)
# INFO:tensorflow:Saving checkpoints for 50000 into belief_net_dir/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-04-27T08:48:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Initialize strategy
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Finished evaluation at 2019-04-27-08:48:52
# INFO:tensorflow:Saving dict for global step 50000: accuracy = 0.923, global_step = 50000, loss = 0.26785156
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: belief_net_dir/model.ckpt-50000
# INFO:tensorflow:Performing best model export.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['predict_output', 'serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from belief_net_dir/model.ckpt-50000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: belief_net_dir/export/best_model/temp-b'1556354932'/saved_model.pb
# INFO:tensorflow:Finalize strategy.
# INFO:tensorflow:Loss for final step: 0.32673097.
# ({'accuracy': 0.923, 'global_step': 50000, 'loss': 0.26785156},
#  [b'belief_net_dir/export/best_model/1556354932'])

# %%
test_img, test_lab = np.reshape(test[0], (10000, -1)), test[1]
test_img = test_img/255

# %%
bn_estimator = tf.estimator.Estimator(model_fn=belief_net_model_fn,
                                      model_dir=model_dir,
                                      config=run_config,
                                      params={})
predictions = bn_estimator.predict(input_fn=data_input_fn(images=test_img, phase='test'),
                                   yield_single_examples=False)
predictions = list(predictions)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'belief_net_dir', '_tf_random_seed': None, '_save_summary_steps': 10, '_save_checkpoints_steps': 500, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': <tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2ac3073c8>, '_device_fn': None, '_protocol': None, '_eval_distribute': <tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2ac307518>, '_experimental_distribute': DistributeConfig(train_distribute=<tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2ac3073c8>, eval_distribute=<tensorflow.contrib.distribute.python.parameter_server_strategy.ParameterServerStrategy object at 0x7fc2ac307518>, remote_cluster=None), '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc2ac3076a0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}

# %%
classes = [np.argmax(x) for x in predictions[0]['probabilities']]

# %%
accuracy_score(y_true=test_lab, y_pred=np.array(classes))
# Out:
# 0.9304

# %%
confusion_matrix(y_true=test_lab, y_pred=np.array(classes))
# Out:
# array([[ 957,    0,    2,    0,    0,    9,    8,    1,    3,    0],
#        [   0, 1116,    3,    5,    0,    2,    4,    0,    5,    0],
#        [  12,    5,  937,   14,   10,    2,   11,   19,   20,    2],
#        [   2,    0,   12,  932,    0,   27,    3,   13,   17,    4],
#        [   0,    1,   13,    0,  915,    0,    4,    3,   12,   34],
#        [   7,    3,    4,   32,    6,  798,   11,    3,   21,    7],
#        [   9,    2,   10,    1,   10,    9,  908,    1,    8,    0],
#        [   3,    6,   22,    4,   11,    1,    0,  947,    5,   29],
#        [   7,    2,    4,   28,    7,   24,    9,    5,  880,    8],
#        [   5,    5,    4,   11,   38,    6,    0,   17,    9,  914]])
